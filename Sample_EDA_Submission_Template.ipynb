# %% [markdown]
# # **Project Name**    - PhonePe Transaction Data Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -sakib patel
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on the analysis of PhonePe digital payment data to understand transaction patterns, user behavior, and regional performance across India. The primary objective of this study is to extract meaningful insights from large-scale transaction data and provide data-driven recommendations to support business decision-making in the digital payments ecosystem.
#
# The dataset used in this project was sourced from the PhonePe Pulse GitHub repository, which contains structured JSON files representing aggregated, map-based, and top-level transaction data. These datasets were systematically extracted and transformed into a tabular format using Python. Libraries such as Pandas, NumPy, Matplotlib, and Seaborn were used for data preprocessing, analysis, and visualization. The data spans multiple years and quarters, enabling both time-series and categorical analysis.
#
# The data preprocessing stage involved cleaning and organizing the dataset to ensure accuracy and consistency. This included handling file structures, standardizing state names, checking for missing or duplicate values, and creating new derived features such as average transaction value. These steps ensured that the dataset was analysis-ready and suitable for generating reliable insights.
#
# Exploratory Data Analysis (EDA) was performed using a variety of visualizations to uncover trends and relationships. Bar charts were used to identify top-performing states in terms of transaction amount and count, while pie charts helped understand the distribution of transaction types. Line charts revealed strong growth trends over the years, indicating increasing adoption of digital payments. Quarterly analysis highlighted seasonal patterns, with higher transaction volumes observed in later quarters. Advanced visualizations such as scatter plots, correlation heatmaps, and pair plots were used to examine relationships between variables, confirming a strong positive correlation between transaction count and transaction amount.
#
# The analysis revealed that states like Maharashtra, Karnataka, and Telangana are leading in digital payment adoption, contributing significantly to overall transaction volume. Transaction types such as peer-to-peer payments and merchant transactions were found to dominate, reflecting common user behavior in everyday financial activities. At the same time, financial services showed lower adoption but higher average transaction values, indicating potential for growth in high-value services.
#
# From a business perspective, the insights derived from this project provide several actionable recommendations. Companies can focus on high-performing regions to maximize revenue while targeting low-performing areas through awareness campaigns and improved accessibility. Enhancing frequently used services and promoting high-value financial offerings can further improve user engagement and profitability. Additionally, understanding seasonal trends allows businesses to optimize marketing strategies and infrastructure during peak periods.
#
# In conclusion, this project demonstrates the importance of data-driven analysis in understanding the digital payment landscape. By leveraging structured data and visualization techniques, valuable insights were generated that can support strategic planning and business growth. The findings highlight both opportunities and challenges within the ecosystem, providing a comprehensive view of user behavior and transaction dynamics. This project also serves as a strong foundation for future work, such as building interactive dashboards and implementing real-time analytics for continuous monitoring and decision-making.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# With the rapid growth of digital payment platforms in India, understanding user behavior, transaction patterns,
# and regional performance has become crucial for businesses. However, large-scale transaction data is often
# complex, unstructured, and difficult to interpret directly.
#
# The PhonePe Pulse dataset contains extensive information about transactions across different states, years,
# quarters, and categories. The challenge is to extract, process, and analyze this data to uncover meaningful
# insights about digital payment usage.
#
# This project aims to perform Exploratory Data Analysis (EDA) on PhonePe transaction data to identify trends,
# patterns, and relationships that can help in understanding the growth and adoption of digital payments across India.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.
# The primary business objective of this project is to analyze PhonePe transaction data to generate actionable insights
# that can support strategic decision-making.
#
# The key objectives include:
#
# 1. Identifying top-performing states and regions based on transaction volume and value.
# 2. Understanding user behavior by analyzing different transaction types and their usage patterns.
# 3. Analyzing growth trends over time to evaluate the adoption of digital payments.
# 4. Detecting seasonal patterns and variations in transaction activity.
# 5. Identifying underperforming regions or services to uncover potential growth opportunities.
#
# By achieving these objectives, the analysis aims to help businesses optimize their services, improve user engagement,
# and expand their reach in the digital payments ecosystem.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Import Libraries
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional settings
plt.rcParams['figure.figsize'] = (10,6)
sns.set_style("whitegrid")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# !git clone https://github.com/PhonePe/pulse.git

# %%
import os

path = "/content/pulse/data/aggregated/transaction/country/india/state/"
print(os.listdir(path))

# %%
import json
import pandas as pd

data_list = []

for state in os.listdir(path):
    for year in os.listdir(path + state):
        for file in os.listdir(path + state + "/" + year):

            with open(path + state + "/" + year + "/" + file) as f:
                data = json.load(f)

                for item in data["data"]["transactionData"]:
                    data_list.append({
                        "state": state,
                        "year": int(year),
                        "quarter": int(file.strip(".json")),
                        "type": item["name"],
                        "count": item["paymentInstruments"][0]["count"],
                        "amount": item["paymentInstruments"][0]["amount"]
                    })

df = pd.DataFrame(data_list)
df.head()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# Dataset Duplicate Value Count
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Missing Values/Null Values Count
df.isnull().sum()

# %%
# Visualizing the missing values
# Visualizing the missing values
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
# The dataset contains aggregated PhonePe transaction data across different states in India.
# It includes details such as transaction type, count, and total transaction amount.
# The dataset spans multiple years and quarters, enabling time-based analysis.
#
# There are no missing values or duplicate records, indicating the dataset is clean and reliable
# for analysis. The data can be used to understand transaction trends, user behavior, and
# regional performance in digital payments.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
# Dataset Columns
df.columns

# %%
# Dataset Describe
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset consists of the following variables:
#
# 1. state: Represents different states of India where transactions occurred.
# 2. year: Indicates the year in which the transaction took place.
# 3. quarter: Represents the quarter of the year (1 to 4).
# 4. type: Denotes the type of transaction such as Recharge, Bill Payment, etc.
# 5. count: Number of transactions performed.
# 6. amount: Total value of transactions in INR.
#
# The dataset includes both categorical variables (state, type) and numerical variables
# (year, quarter, count, amount), enabling both statistical and categorical analysis.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Unique values count
for col in df.columns:
    print(col, ":", df[col].nunique())

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Make a copy of dataset
df_clean = df.copy()

# 1. Standardize state names
df_clean["state"] = df_clean["state"].str.replace("-", " ").str.title()

# 2. Check and remove duplicates
df_clean = df_clean.drop_duplicates()

# 3. Check missing values
print(df_clean.isnull().sum())

# 4. Convert data types (safety step)
df_clean["year"] = df_clean["year"].astype(int)
df_clean["quarter"] = df_clean["quarter"].astype(int)

# 5. Create new useful features

# Total transaction in lakhs (better readability)
df_clean["amount_lakhs"] = df_clean["amount"] / 100000

# Transactions per unit (efficiency metric)
df_clean["avg_transaction_value"] = df_clean["amount"] / df_clean["count"]

# 6. Sort values for analysis
df_clean = df_clean.sort_values(by=["year", "quarter"])

# Final check
df_clean.head()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
# Several data preprocessing steps were performed to make the dataset analysis-ready.
#
# 1. State names were standardized by replacing hyphens with spaces and converting them into proper title case for better readability.
#
# 2. Duplicate records were checked and removed to ensure data integrity.
#
# 3. Missing values were analyzed, and it was found that the dataset contained no null values, indicating clean data.
#
# 4. Data types were verified and converted where necessary to maintain consistency.
#
# 5. New features were created to enhance analysis:
#    - Transaction amount in lakhs for better visualization.
#    - Average transaction value to understand user spending behavior.
#
# 6. The dataset was sorted by year and quarter to facilitate time-based analysis.
#
# Insights:
# - The dataset is clean and well-structured with no missing values.
# - Transaction values vary significantly across states and categories.
# - The derived metric (average transaction value) helps identify high-value transaction patterns.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Chart - 1: Top States by Transaction Amount

top_states = df_clean.groupby("state")["amount"].sum().sort_values(ascending=False).head(10)

import matplotlib.pyplot as plt

plt.figure()
top_states.plot(kind="bar")
plt.title("Top 10 States by Transaction Amount")
plt.xticks(rotation=45)
plt.ylabel("Transaction Amount")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A bar chart was chosen because it is the most effective way to compare transaction amounts across different states.
# It provides a clear visual comparison and helps in identifying top-performing regions quickly.
# Bar charts are ideal for categorical data where ranking and magnitude differences are important.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows that states like Maharashtra, Karnataka, and Telangana have the highest transaction amounts,
# indicating strong digital payment adoption in these regions.
#
# There is a noticeable gap between top-performing states and others, suggesting uneven distribution of digital
# payment usage across the country.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# The company can focus on high-performing states to enhance services, improve infrastructure, and launch targeted
# marketing campaigns. These regions can be leveraged for introducing new features and maximizing revenue.
#
# Negative Growth Insight:
# States with lower transaction volumes indicate slower adoption of digital payments, which may be due to limited
# internet access, lack of awareness, or lower digital literacy.
#
# Justification:
# These insights help identify growth opportunities. By targeting low-performing regions with awareness programs,
# better accessibility, and incentives, the company can increase adoption and expand its user base.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Chart - 2: Transaction Type Distribution

type_data = df_clean.groupby("type")["amount"].sum()

import matplotlib.pyplot as plt

plt.figure()
type_data.plot(kind="pie", autopct="%1.1f%%")
plt.title("Transaction Type Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A pie chart was selected because it is ideal for representing the proportion of different transaction types
# in the overall dataset. It helps in understanding how each category contributes to the total transaction amount.
# This type of chart makes it easy to quickly identify dominant and less-used transaction categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart reveals that certain transaction types, such as merchant payments and peer-to-peer transfers,
# contribute the largest share of the total transaction amount. This indicates that users heavily rely on
# digital platforms for everyday payments and money transfers.
#
# Other categories like recharge and financial services contribute a smaller portion, suggesting relatively
# lower usage compared to the dominant categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# The company can focus on improving and promoting the most widely used transaction categories, such as
# merchant payments and peer-to-peer transfers, to enhance user experience and increase engagement.
# These insights also help in prioritizing investments in high-performing services.
#
# Negative Growth Insight:
# The lower contribution of certain categories like financial services may indicate limited user adoption.
# This could be due to lack of awareness, trust issues, or complex user interfaces.
#
# Justification:
# Identifying underperforming categories allows the business to take corrective actions such as simplifying
# services, improving user education, and offering incentives. This can help increase adoption and overall growth.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Chart - 3: Yearly Transaction Trend

yearly = df_clean.groupby("year")["amount"].sum()

import matplotlib.pyplot as plt

plt.figure()
yearly.plot(marker='o')
plt.title("Yearly Transaction Trend")
plt.xlabel("Year")
plt.ylabel("Transaction Amount")
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A line chart was chosen because it is the most suitable visualization for analyzing trends over time.
# It clearly shows how transaction amounts change across different years, making it easy to identify growth patterns
# and fluctuations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows a consistent upward trend in transaction amounts over the years, indicating rapid growth
# in digital payment adoption.
#
# A significant increase is observed after 2020, which may be influenced by increased digital usage and
# changing consumer behavior. This reflects strong growth in the digital payments ecosystem.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# The steady growth trend indicates increasing user adoption and trust in digital payment platforms.
# This encourages businesses to invest further in digital infrastructure, introduce new features,
# and expand services to meet growing demand.
#
# Negative Growth Insight:
# If any fluctuations or slower growth are observed in certain years, it may indicate external factors
# such as economic slowdowns or market saturation.
#
# Justification:
# Understanding these patterns helps businesses prepare for uncertainties and adapt strategies accordingly.
# By analyzing growth trends, companies can make informed decisions to sustain long-term expansion and
# improve overall performance.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Chart - 4: Quarter-wise Transaction Analysis

quarterly = df_clean.groupby("quarter")["amount"].sum()

import matplotlib.pyplot as plt

plt.figure()
quarterly.plot(kind="bar")
plt.title("Quarter-wise Transaction Amount")
plt.xlabel("Quarter")
plt.ylabel("Transaction Amount")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A bar chart was chosen because it effectively compares transaction amounts across discrete categories,
# in this case, quarters. It provides a clear visual representation of how transactions vary within a year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows that transaction amounts tend to increase in later quarters, with Q4 having the highest
# transaction volume. This suggests higher user activity toward the end of the year, possibly due to festivals,
# sales, and increased spending behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# Understanding quarterly trends helps businesses plan marketing campaigns, promotional offers, and system
# scalability during peak periods such as Q4. It enables better resource allocation and improved customer experience.
#
# Negative Growth Insight:
# Lower transaction volumes in earlier quarters (such as Q1) may indicate reduced user activity or seasonal slowdown.
#
# Justification:
# By identifying low-performing periods, businesses can introduce targeted campaigns, discounts, and engagement
# strategies to boost activity during those times, ensuring more consistent growth throughout the year.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Chart - 5: Top States Comparison (Detailed)

top_states = df_clean.groupby("state")["amount"].sum().sort_values(ascending=False).head(5)

import matplotlib.pyplot as plt

plt.figure()
top_states.plot(kind="bar")
plt.title("Top 5 States by Transaction Amount")
plt.xlabel("State")
plt.ylabel("Transaction Amount")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A bar chart was chosen because it provides a clear comparison between the top-performing states.
# It helps in easily identifying which states contribute the most to total transaction volume.
# Bar charts are effective for ranking and comparing categorical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows that Maharashtra, Karnataka, and Telangana are the leading states in terms of transaction amount.
# This indicates a high level of digital payment adoption and user engagement in these regions.
#
# There is also a visible gap between top-performing states and others, highlighting regional differences
# in digital payment usage.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# The company can focus on strengthening its presence in high-performing states by improving services,
# introducing new features, and targeting premium users. These regions can be used as benchmarks for growth strategies.
#
# Negative Growth Insight:
# Lower-performing states indicate slower adoption of digital payments, which may be due to lack of infrastructure,
# awareness, or digital literacy.
#
# Justification:
# These insights help identify untapped markets. By improving accessibility, running awareness campaigns,
# and offering incentives, the company can boost adoption in these regions and achieve balanced growth.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Chart - 6: Average Transaction Value by State

avg_value = df_clean.groupby("state").apply(lambda x: x["amount"].sum() / x["count"].sum())
avg_value = avg_value.sort_values(ascending=False).head(5)

import matplotlib.pyplot as plt

plt.figure()
avg_value.plot(kind="bar")
plt.title("Top States by Average Transaction Value")
plt.xlabel("State")
plt.ylabel("Average Transaction Value")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A bar chart was chosen to compare the average transaction value across different states.
# This helps in identifying which states have higher-value transactions, providing deeper insights beyond
# just total transaction volume.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows that states like Maharashtra and Karnataka have higher average transaction values,
# indicating that users in these regions tend to perform higher-value transactions.
#
# This suggests stronger purchasing power or higher usage of premium digital payment services in these states.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# High average transaction values indicate premium user segments. The company can target these users
# with advanced features, financial services, and personalized offers to increase revenue.
#
# Negative Growth Insight:
# States with lower average transaction values may indicate lower purchasing power or limited usage of
# high-value services.
#
# Justification:
# These insights help businesses design targeted strategies for different user segments. By improving
# accessibility and promoting high-value services in low-performing regions, the company can enhance
# overall transaction quality and growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Chart - 7: Transaction Count vs Amount

import matplotlib.pyplot as plt

plt.figure()
plt.scatter(df_clean["count"], df_clean["amount"])
plt.title("Transaction Count vs Transaction Amount")
plt.xlabel("Transaction Count")
plt.ylabel("Transaction Amount")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A scatter plot was chosen because it is ideal for analyzing the relationship between two numerical variables.
# It helps in understanding how transaction count affects the total transaction amount and whether there is
# a correlation between them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows a positive correlation between transaction count and transaction amount.
# As the number of transactions increases, the total transaction value also increases.
#
# This indicates that higher user activity leads to higher transaction volumes, reflecting strong engagement
# on the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# The strong correlation suggests that increasing user activity directly contributes to higher transaction volume.
# This means that strategies focused on boosting engagement, such as cashback offers and promotions, can
# significantly increase revenue.
#
# Negative Growth Insight:
# If certain data points show high transaction count but relatively low transaction value, it may indicate
# low-value transactions dominating user behavior.
#
# Justification:
# This insight helps businesses identify user behavior patterns. By encouraging higher-value transactions
# through incentives or premium services, the company can improve overall transaction quality and profitability.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Chart - 8: Transaction Type by Count

type_count = df_clean.groupby("type")["count"].sum().sort_values(ascending=False)

import matplotlib.pyplot as plt

plt.figure()
type_count.plot(kind="bar")
plt.title("Transaction Types by Count")
plt.xlabel("Transaction Type")
plt.ylabel("Transaction Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A bar chart was chosen to compare transaction frequency across different categories.
# It clearly shows which transaction types are most commonly used by users, making it easy to analyze
# user behavior patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows that peer-to-peer transactions and merchant payments have the highest transaction counts,
# indicating that users frequently use digital platforms for money transfers and daily purchases.
#
# Financial services have significantly lower transaction counts, suggesting lower adoption in this category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# The company can focus on optimizing high-frequency services like peer-to-peer and merchant payments to
# enhance user experience and reliability. These categories drive user engagement and platform usage.
#
# Negative Growth Insight:
# The low transaction count in financial services indicates underutilization, which may be due to lack of
# awareness, complexity, or trust issues.
#
# Justification:
# This insight helps identify growth opportunities. By improving user education, simplifying processes,
# and building trust, the company can increase adoption of financial services and expand its offerings.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Chart - 9: Quarter Trend Line Chart

quarterly = df_clean.groupby("quarter")["amount"].sum()

import matplotlib.pyplot as plt

plt.figure()
quarterly.plot(marker='o')
plt.title("Quarter-wise Transaction Trend")
plt.xlabel("Quarter")
plt.ylabel("Transaction Amount")
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A line chart was chosen because it effectively shows trends and patterns over ordered data, such as quarters.
# It helps visualize how transaction amounts change across different periods within a year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows a rising trend in transaction amounts from Q1 to Q4, indicating increasing user activity
# throughout the year. The highest transactions occur in Q4, suggesting peak usage during this period.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# The company can plan marketing campaigns, promotional offers, and system upgrades during high-activity periods
# like Q4 to maximize performance and customer satisfaction.
#
# Negative Growth Insight:
# Lower transaction levels in earlier quarters, such as Q1, may indicate seasonal slowdown or reduced engagement.
#
# Justification:
# These insights help businesses optimize strategies throughout the year. By boosting engagement during low-performing
# periods and maximizing opportunities during peak seasons, companies can achieve more consistent growth.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Chart - 10: Yearly Transaction Count Trend

yearly_count = df_clean.groupby("year")["count"].sum()

import matplotlib.pyplot as plt

plt.figure()
yearly_count.plot(marker='o')
plt.title("Yearly Transaction Count Trend")
plt.xlabel("Year")
plt.ylabel("Transaction Count")
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A line chart was chosen because it is ideal for visualizing trends over time.
# It clearly shows how transaction count has evolved across years, helping to identify growth patterns
# in user activity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows a strong upward trend in transaction count over the years, indicating rapid growth
# in the number of digital transactions.
#
# This suggests increasing user adoption and higher engagement with digital payment platforms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# The continuous growth in transaction count indicates increasing platform usage, encouraging businesses
# to invest in infrastructure, scalability, and new features to support growing demand.
#
# Negative Growth Insight:
# If any year shows slower growth compared to others, it may indicate market saturation or external challenges
# affecting user activity.
#
# Justification:
# Understanding these trends helps businesses plan long-term strategies, improve system performance,
# and maintain user satisfaction as the platform scales.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Chart - 11: Top States by Transaction Count

top_states_count = df_clean.groupby("state")["count"].sum().sort_values(ascending=False).head(10)

import matplotlib.pyplot as plt

plt.figure()
top_states_count.plot(kind="bar")
plt.title("Top 10 States by Transaction Count")
plt.xlabel("State")
plt.ylabel("Transaction Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A bar chart was chosen because it effectively compares transaction activity across different states.
# It clearly shows which regions have the highest number of transactions, making it easy to analyze user engagement levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows that states like Maharashtra, Karnataka, and Telangana have the highest transaction counts,
# indicating strong user engagement and frequent usage of digital payment platforms.
#
# It also highlights differences between states, suggesting varying levels of digital adoption across regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# High transaction counts indicate active user bases. The company can focus on retaining these users by improving
# services, offering rewards, and introducing new features.
#
# Negative Growth Insight:
# States with lower transaction counts indicate lower engagement, which may be due to limited digital access,
# awareness, or infrastructure challenges.
#
# Justification:
# These insights help identify both strong and weak markets. By targeting low-performing regions with awareness
# campaigns and improving accessibility, the company can increase adoption and achieve balanced growth.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization
# Chart - 12: Average Transaction Value (Detailed)

avg_value = df_clean.groupby("state").apply(lambda x: x["amount"].sum() / x["count"].sum())
avg_value = avg_value.sort_values(ascending=False).head(6)

import matplotlib.pyplot as plt

plt.figure()
avg_value.plot(kind="bar")
plt.title("Top States by Average Transaction Value")
plt.xlabel("State")
plt.ylabel("Average Transaction Value")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A bar chart was chosen to compare average transaction values across different states.
# This helps in identifying regions with higher-value transactions, providing insights into user spending behavior
# beyond just transaction volume.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows that states like Maharashtra and Karnataka have higher average transaction values,
# indicating stronger purchasing power and higher-value digital transactions.
#
# Other states show comparatively lower values, suggesting differences in economic activity and user behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# States with higher average transaction values represent premium user segments. Businesses can target these regions
# with advanced financial services, investment products, and personalized offers to increase revenue.
#
# Negative Growth Insight:
# States with lower average transaction values may indicate lower purchasing power or limited adoption of high-value services.
#
# Justification:
# These insights help businesses segment markets effectively. By promoting financial services and improving accessibility
# in lower-performing regions, companies can enhance transaction value and drive balanced growth.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Chart - 13: Average Transaction Value by Type

avg_type = df_clean.groupby("type").apply(lambda x: x["amount"].sum() / x["count"].sum())

import matplotlib.pyplot as plt

plt.figure()
avg_type.plot(kind="bar")
plt.title("Average Transaction Value by Type")
plt.xlabel("Transaction Type")
plt.ylabel("Average Transaction Value")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A bar chart was chosen to compare average transaction values across different transaction types.
# This helps in identifying which categories involve higher-value transactions, providing deeper insights
# into user spending behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The chart shows that financial services have the highest average transaction value, indicating that
# these transactions are less frequent but involve higher amounts.
#
# Merchant payments and peer-to-peer transactions show moderate values, while recharge and bill payments
# have lower average transaction values, indicating smaller but frequent transactions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Yes, the insights gained can create a positive business impact.
#
# Positive Impact:
# High-value categories like financial services can be targeted for premium offerings, investment products,
# and personalized financial solutions to increase revenue.
#
# Negative Growth Insight:
# Lower average values in categories like recharge may indicate limited revenue potential per transaction,
# even though frequency is high.
#
# Justification:
# These insights help businesses balance between high-frequency and high-value services. By promoting
# higher-value services and optimizing frequent transactions, companies can maximize both engagement and profitability.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Chart - 14: Correlation Heatmap

import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
corr = df_clean[["year", "quarter", "count", "amount"]].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A heatmap was chosen because it effectively visualizes the correlation between numerical variables.
# It helps in identifying strong and weak relationships between variables such as transaction count and amount
# in an intuitive and color-coded manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The heatmap shows a strong positive correlation between transaction count and transaction amount,
# indicating that as the number of transactions increases, the total transaction value also increases.
#
# Other variables like year also show positive correlation, suggesting growth over time in both transaction
# volume and value.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Chart - 15: Pair Plot

import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant numeric columns
sns.pairplot(df_clean[["year", "quarter", "count", "amount"]])

plt.suptitle("Pair Plot of Numerical Variables", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# A pair plot was chosen because it allows visualization of relationships between multiple numerical variables simultaneously.
# It helps in identifying patterns, correlations, and distributions across variables such as year, quarter, transaction count, and amount.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# The pair plot reveals a strong positive relationship between transaction count and transaction amount, confirming that
# higher activity leads to higher transaction value.
#
# It also shows trends over time, where both count and amount increase with year, indicating growth in digital payment usage.
# The distribution plots highlight how data is spread across different variables.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
# Based on the analysis of PhonePe transaction data, several actionable recommendations can be made to help achieve the business objectives:
#
# 1. Focus on High-Performing Regions:
# States like Maharashtra, Karnataka, and Telangana show high transaction volumes and values. The company should strengthen its presence in these regions by introducing advanced features, loyalty programs, and premium services to maximize revenue.
#
# 2. Improve Adoption in Low-Performing Regions:
# Some states show lower transaction activity, indicating untapped potential. The company should focus on increasing awareness, improving digital accessibility, and offering incentives such as cashback and discounts to boost adoption.
#
# 3. Enhance High-Frequency Services:
# Transaction types like peer-to-peer payments and merchant payments are widely used. Improving the speed, reliability, and user experience of these services can increase user satisfaction and retention.
#
# 4. Promote High-Value Services:
# Financial services and high-value transactions show strong potential but lower adoption. The company should promote these services through targeted campaigns, simplified interfaces, and trust-building measures.
#
# 5. Leverage Seasonal Trends:
# Higher transaction activity is observed in later quarters (especially Q4). The company should plan marketing campaigns, offers, and infrastructure scaling during peak periods to maximize performance.
#
# 6. Increase User Engagement:
# Since transaction count directly impacts transaction amount, strategies like referral programs, rewards, and personalized offers can encourage more frequent usage.
#
# 7. Data-Driven Decision Making:
# Continuous monitoring of transaction trends, user behavior, and regional performance can help the company make informed decisions and adapt strategies dynamically.
#
# Conclusion:
# By focusing on high-performing areas, improving low-performing regions, and enhancing both user experience and service offerings, the company can achieve sustainable growth and strengthen its position in the digital payments market.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
# This project analyzed PhonePe transaction data to understand user behavior, transaction trends, and regional performance across India.
# Through data extraction, preprocessing, and visualization, meaningful insights were derived from a large and structured dataset.
#
# The analysis revealed a strong growth in digital payments over the years, with significant increases in both transaction count and amount.
# Certain states such as Maharashtra, Karnataka, and Telangana emerged as top performers, indicating high digital adoption and engagement.
# Transaction types like peer-to-peer payments and merchant transactions were found to dominate, reflecting everyday usage patterns.
#
# Additionally, the study highlighted seasonal trends, with higher activity observed in later quarters, and demonstrated a strong positive
# correlation between transaction count and transaction amount. Advanced visualizations such as heatmaps and pair plots further confirmed
# key relationships within the data.
#
# From a business perspective, the insights suggest opportunities for targeted marketing, improving services in low-performing regions,
# and promoting high-value financial services. The findings emphasize the importance of data-driven decision-making in enhancing user
# experience and driving business growth.
#
# Overall, this project provides a comprehensive understanding of the digital payment ecosystem and offers valuable recommendations
# for optimizing performance and expanding market reach.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
